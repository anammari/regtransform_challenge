# %%
# %run -i main.py
# Out:
# Torch version: 1.4.0
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [{'boxes': tensor([[ 188., 1103., 1473., 1306.],
#         [ 251., 1910.,  667., 1980.],
#         [ 185.,  117., 1610.,  487.],
#         [ 181.,  497., 1536., 1086.]]), 'labels': tensor([1, 1, 1, 1]), 'image_id': tensor([185]), 'area': tensor([260855.,  29120., 527250., 798095.]), 'iscrowd': tensor([0, 0, 0, 0])}]
# [{'boxes': tensor([[1560., 1003., 1561., 1006.],
#         [ 175., 1553., 1417., 1969.],
#         [ 128.,  180.,  494.,  266.],
#         [ 155.,  293., 1537.,  479.],
#         [ 111.,  510., 1536.,  653.],
#         [ 121.,  663., 1530.,  819.]]), 'labels': tensor([1, 1, 1, 1, 1, 1]), 'image_id': tensor([108]), 'area': tensor([3.0000e+00, 5.1667e+05, 3.1476e+04, 2.5705e+05, 2.0378e+05, 2.1980e+05]), 'iscrowd': tensor([0, 0, 0, 0, 0, 0])}]
# ...
